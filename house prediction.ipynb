# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\marcell suyanto\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\marcell suyanto\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\marcell suyanto\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: seaborn in c:\users\marcell suyanto\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\marcell suyanto\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\marcell suyanto\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %% [markdown]
# X is the dataframe without target variable,
# Y is the dataframe with only the target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# Split the data into training and testing data (80/20 split)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19830    -119.38     36.55                31.0       2342.0           439.0
# 41       -122.26     37.83                51.0        936.0           311.0
# 13403    -117.47     34.12                 6.0      10565.0          1767.0
# 20607    -121.57     39.10                28.0       1442.0           333.0
# 3054     -119.34     35.60                33.0       2143.0           488.0
# ...          ...       ...                 ...          ...             ...
# 10380    -117.63     33.62                 9.0       4257.0           785.0
# 1280     -121.80     38.01                46.0       2273.0           495.0
# 6233     -117.95     34.07                37.0       1375.0           260.0
# 2702     -115.57     32.85                17.0       1039.0           256.0
# 16677    -120.66     35.13                41.0       2666.0           751.0
#
#        population  households  median_income ocean_proximity  \
# 19830      1411.0       465.0         3.0170          INLAND
# 41          517.0       249.0         1.2852        NEAR BAY
# 13403      5690.0      1555.0         4.1797          INLAND
# 20607       832.0       286.0         1.8413          INLAND
# 3054       1732.0       509.0         1.9362          INLAND
# ...           ...         ...            ...             ...
# 10380      1293.0       745.0         3.7139       <1H OCEAN
# 1280       1088.0       447.0         2.2532          INLAND
# 6233        951.0       272.0         3.2083       <1H OCEAN
# 2702        728.0       246.0         1.7411          INLAND
# 16677       940.0       507.0         1.9653       <1H OCEAN
#
#        median_house_value
# 19830             72000.0
# 41               150000.0
# 13403            141000.0
# 20607             62300.0
# 3054              59000.0
# ...                   ...
# 10380            196700.0
# 1280             109400.0
# 6233             195200.0
# 2702              63500.0
# 16677            236100.0
#
# [15324 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Shows correlation between columns. "median_income" has highest correlation with our target value (0.69)

# %% [markdown]
# Data Processing

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# 1 Hot encoding

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19830    -119.38     36.55                31.0     7.759187        6.086775
# 41       -122.26     37.83                51.0     6.842683        5.743003
# 13403    -117.47     34.12                 6.0     9.265397        7.477604
# 20607    -121.57     39.10                28.0     7.274480        5.811141
# 3054     -119.34     35.60                33.0     7.670429        6.192362
# ...          ...       ...                 ...          ...             ...
# 10380    -117.63     33.62                 9.0     8.356555        6.666957
# 1280     -121.80     38.01                46.0     7.729296        6.206576
# 6233     -117.95     34.07                37.0     7.226936        5.564520
# 2702     -115.57     32.85                17.0     6.946976        5.549076
# 16677    -120.66     35.13                41.0     7.888710        6.622736
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 19830    7.252762    6.144186         3.0170             72000.0      False
# 41       6.249975    5.521461         1.2852            150000.0      False
# 13403    8.646641    7.349874         4.1797            141000.0      False
# 20607    6.725034    5.659482         1.8413             62300.0      False
# 3054     7.457609    6.234411         1.9362             59000.0      False
# ...           ...         ...            ...                 ...        ...
# 10380    7.165493    6.614726         3.7139            196700.0       True
# 1280     6.993015    6.104793         2.2532            109400.0      False
# 6233     6.858565    5.609472         3.2083            195200.0       True
# 2702     6.591674    5.509388         1.7411             63500.0      False
# 16677    6.846943    6.230481         1.9653            236100.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 19830    True   False     False       False
# 41      False   False      True       False
# 13403    True   False     False       False
# 20607    True   False     False       False
# 3054     True   False     False       False
# ...       ...     ...       ...         ...
# 10380   False   False     False       False
# 1280     True   False     False       False
# 6233    False   False     False       False
# 2702     True   False     False       False
# 16677   False   False     False       False
#
# [15324 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data['household_rooms'] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression


X_train, y_train = train_data.drop(["median_house_value"], axis=1), train_data["median_house_value"]


reg = LinearRegression()

reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data['household_rooms'] = test_data["total_rooms"] / test_data["households"]

# %%
X_test, y_test = test_data.drop(["median_house_value"], axis=1), test_data["median_house_value"]

# %%
reg.score(X_test, y_test)
# Out:
# 0.6666081243060187

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.8148437663502904

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()


param_grid = {
    "n_estimators" : [100,200,300],
    "min_samples_split": [2,4],
    "max_depth": [None,4,8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test, y_test)
# Out:
# 0.8151425107975809
